# %% [markdown]
# <a href="https://colab.research.google.com/github/pathilink/Kaggle/blob/master/Data_Jobs_Listings_Glassdoor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Jobs Listings - Glassdoor
#
# The purpose of this notebook is to select data related to data jobs in Brazil.
#
# https://www.kaggle.com/andresionek/data-jobs-listings-glassdoor

# %%
# Libraries
import pandas as pd
import json

# %% [markdown]
# ### Kaggle API key

# %%
# Kaggle API key
# !pip install kaggle
# !mkdir ~/.kaggle
# !touch '/root/.kaggle/kaggle.json'
######################################################################################
# Copy USER NAME and API KEY from Kaggle
# api_token = {"username":"username","key":"TOKEN_HERE"}

api_token = {"username":"","key":""}
######################################################################################

with open('/root/.kaggle/kaggle.json', 'w') as file:
    json.dump(api_token, file)

# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.8)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.6.20)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.1)
# Requirement already satisfied: slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (0.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# Download dataset
# !kaggle datasets download -d andresionek/data-jobs-listings-glassdoor
# Out:
# data-jobs-listings-glassdoor.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# If you get the "Unauthorized" error as a result of this cell:
# 1. Delete the file kaggle.json with the following command: !rm /root/.kaggle/kaggle.json
# 2. Check or regenerate the Kaggle token.

# %%
# Unzip the compressed file
# !unzip data-jobs-listings-glassdoor.zip
# Out:
# Archive:  data-jobs-listings-glassdoor.zip
# replace country_names_2_digit_codes.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: country_names_2_digit_codes.csv
#   inflating: currency_exchange.csv
#   inflating: glassdoor.csv           A
#
#   inflating: glassdoor_benefits_comments.csv
#   inflating: glassdoor_benefits_highlights.csv
#   inflating: glassdoor_breadCrumbs.csv
#   inflating: glassdoor_overview_competitors.csv
#   inflating: glassdoor_photos.csv
#   inflating: glassdoor_reviews.csv   A
#
#   inflating: glassdoor_reviews_val_reviewResponses.csv
#   inflating: glassdoor_salary_salaries.csv
#   inflating: glassdoor_wwfu.csv
#   inflating: glassdoor_wwfu_val_captions.csv
#   inflating: glassdoor_wwfu_val_photos.csv
#   inflating: glassdoor_wwfu_val_videos.csv

# %%
# List available files
# !ls
# Out:
# country_names_2_digit_codes.csv     glassdoor_reviews.csv
# currency_exchange.csv		    glassdoor_reviews_val_reviewResponses.csv
# data-jobs-listings-glassdoor.zip    glassdoor_salary_salaries.csv
# glassdoor_benefits_comments.csv     glassdoor_wwfu.csv
# glassdoor_benefits_highlights.csv   glassdoor_wwfu_val_captions.csv
# glassdoor_breadCrumbs.csv	    glassdoor_wwfu_val_photos.csv
# glassdoor.csv			    glassdoor_wwfu_val_videos.csv
# glassdoor_overview_competitors.csv  sample_data
# glassdoor_photos.csv

# %% [markdown]
# ### Display configuration

# %%
# display all columns
pd.set_option('max_columns', None)

# display all rows
#pd.set_option('max_rows', None)

# display the entire column width 
#pd.set_option('max_colwidth', None)

# display all values of an item
#pd.set_option('max_seq_item', None)

# %%
# Load data with labels
glassdoor = pd.read_csv('glassdoor.csv')
print("Dataset dimension (rows, columns): ", glassdoor.shape)
glassdoor.sample(5)
# Out:
# Dataset dimension (rows, columns):  (165290, 163)
#         benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 38076                           0.000            11677.0              11677.0
# 15224                           3.875           114024.0             114024.0
# 94189                           0.000            36900.0              36900.0
# 118571                          0.000            62082.0              62082.0
# 29671                           0.000           112071.0             112071.0
#
#         benefits.numRatings benefits.employerSummary  breadCrumbs  \
# 38076                     0                      NaN        11677
# 15224                     8                      NaN       114025
# 94189                     0                      NaN        36900
# 118571                    0                      NaN        62082
# 29671                     0                      NaN       112072
#
#         gaTrackerData.category  gaTrackerData.empId gaTrackerData.empName  \
# 38076                       -1               505617      NZ Defence Force
# 15224                       -1               408251               Spotify
# 94189                       -1                40988                   IBA
# 118571                      -1               266447                OPSWAT
# 29671                       -1              1925330    Helvetica Partners
#
#        gaTrackerData.empSize  gaTrackerData.expired  \
# 38076               10000--1                  False
# 15224              1001-5000                  False
# 94189              1001-5000                  False
# 118571               201-500                  False
# 29671                   1-50                  False
#
#                          gaTrackerData.industry  gaTrackerData.industryId  \
# 38076                          Federal Agencies                    200056
# 15224                                  Internet                    200063
# 94189        Health Care Products Manufacturing                    200072
# 118571  Enterprise Software & Network Solutions                    200061
# 29671                                       NaN                         0
#
#         gaTrackerData.jobId.long  gaTrackerData.jobId.int  \
# 38076               3.400759e+09                      NaN
# 15224               3.205275e+09                      NaN
# 94189               3.383648e+09                      NaN
# 118571              3.388111e+09                      NaN
# 29671               3.158804e+09                      NaN
#
#                                 gaTrackerData.jobTitle gaTrackerData.location  \
# 38076     Science Researcher Human Systems Integration              Devonport
# 15224        Engineering Manager - Cash-To-Settlements                    NaN
# 94189   Service Engineer (electrical) - Proton Therapy                    NaN
# 118571             Senior Software Engineering Manager       Ho Chi Minh City
# 29671                      Senior SAP Security Analyst                 Zürich
#
#         gaTrackerData.locationId gaTrackerData.locationType  \
# 38076                    4687358                       CITY
# 15224                    3283253                       CITY
# 94189                         -1                       CITY
# 118571                   2748023                       CITY
# 29671                    3297851                       CITY
#
#        gaTrackerData.pageRequestGuid.guid  \
# 38076    0000016e56f397aa8803dbe5ba4cae6c
# 15224    0000016e57c8b695b1de53d382a2e682
# 94189    0000016e576a2f5a8b812fe18d16537a
# 118571   0000016e5785bf42ad1012ca699a9a74
# 29671    0000016e57c607588d4e13a24ad75739
#
#         gaTrackerData.pageRequestGuid.guidValid  \
# 38076                                      True
# 15224                                      True
# 94189                                      True
# 118571                                     True
# 29671                                      True
#
#         gaTrackerData.pageRequestGuid.part1  \
# 38076                         1573416834986
# 15224                         1573430802069
# 94189                         1573424607066
# 118571                        1573426413378
# 29671                         1573430626136
#
#         gaTrackerData.pageRequestGuid.part2    gaTrackerData.sector  \
# 38076                  -8645825079901639060              Government
# 15224                  -5629970316271622526  Information Technology
# 94189                  -8394375584660696198           Manufacturing
# 118571                 -5976256044956214668  Information Technology
# 29671                  -8264646678417025223                     NaN
#
#         gaTrackerData.sectorId  \
# 38076                    10011
# 15224                    10013
# 94189                    10015
# 118571                   10013
# 29671                        0
#
#        gaTrackerData.profileConversionTrackingParams.trackingCAT  \
# 38076                                                 NaN
# 15224                                                 NaN
# 94189                                                 NaN
# 118571                                                NaN
# 29671                                                 NaN
#
#         gaTrackerData.profileConversionTrackingParams.trackingSRC  \
# 38076                                                 NaN
# 15224                                                 NaN
# 94189                                                 NaN
# 118571                                                NaN
# 29671                                                 NaN
#
#         gaTrackerData.profileConversionTrackingParams.trackingXSP  \
# 38076                                                 NaN
# 15224                                                 NaN
# 94189                                                 NaN
# 118571                                                NaN
# 29671                                                 NaN
#
#         gaTrackerData.jobViewTrackingResult.jobViewDisplayTimeMillis  \
# 38076                                                 NaN
# 15224                                                 NaN
# 94189                                                 NaN
# 118571                                                NaN
# 29671                                                 NaN
#
#        gaTrackerData.jobViewTrackingResult.requiresTracking  \
# 38076                                                 NaN
# 15224                                                 NaN
# 94189                                                 NaN
# 118571                                                NaN
# 29671                                                 NaN
#
#        gaTrackerData.jobViewTrackingResult.trackingUrl  header.adOrderId  \
# 38076                                              NaN            437149
# 15224                                              NaN            636764
# 94189                                              NaN            437149
# 118571                                             NaN             37049
# 29671                                              NaN            437149
#
#        header.advertiserType  header.applicationId  \
# 38076                GENERAL                     0
# 15224               EMPLOYER                     0
# 94189                GENERAL                     0
# 118571               GENERAL                     0
# 29671                GENERAL                     0
#
#         header.applyButtonDisabled  \
# 38076                        False
# 15224                        False
# 94189                        False
# 118571                       False
# 29671                        False
#
#                                           header.applyUrl  header.blur  \
# 38076   /partner/jobListing.htm?pos=101&ao=437149&s=58...         True
# 15224   /partner/jobListing.htm?pos=101&ao=636764&s=58...        False
# 94189   /partner/jobListing.htm?pos=101&ao=437149&s=58...         True
# 118571  /partner/jobListing.htm?pos=101&ao=37049&s=58&...         True
# 29671   /partner/jobListing.htm?pos=101&ao=437149&tgt=...         True
#
#                                         header.coverPhoto  header.easyApply  \
# 38076           /static/img/banners/default-ei-banner.jpg             False
# 15224   https://media.glassdoor.com/banner/bh/408251/s...             False
# 94189           /static/img/banners/default-ei-banner.jpg             False
# 118571          /static/img/banners/default-ei-banner.jpg             False
# 29671           /static/img/banners/default-ei-banner.jpg              True
#
#         header.employerId        header.employerName  header.expired  \
# 38076              505617  New Zealand Defence Force           False
# 15224              408251                    Spotify           False
# 94189               40988                        IBA           False
# 118571             266447                     OPSWAT           False
# 29671             1925330         Helvetica Partners           False
#
#         header.gocId  header.hideCEOInfo  \
# 38076             -1               False
# 15224             -1               False
# 94189             -1               False
# 118571            -1               False
# 29671             -1               False
#
#                                        header.jobTitle  header.locId  \
# 38076     Science Researcher Human Systems Integration       4687358
# 15224        Engineering Manager - Cash-To-Settlements       3283253
# 94189   Service Engineer (electrical) - Proton Therapy            25
# 118571             Senior Software Engineering Manager       2748023
# 29671                      Senior SAP Security Analyst       3297851
#
#          header.location header.locationType  \
# 38076          Devonport                   C
# 15224          Stockholm                   C
# 94189            Belgium                   N
# 118571  Ho Chi Minh City                   C
# 29671             Zürich                   C
#
#                                               header.logo  \
# 38076   https://media.glassdoor.com/sqls/505617/nz-def...
# 15224   https://media.glassdoor.com/sqls/408251/spotif...
# 94189   https://media.glassdoor.com/sqls/40988/iba-squ...
# 118571  https://media.glassdoor.com/sqls/266447/opswat...
# 29671   https://media.glassdoor.com/sqls/1925330/helve...
#
#                                             header.logo2x  header.organic  \
# 38076   https://media.glassdoor.com/sqlm/505617/nz-def...            True
# 15224   https://media.glassdoor.com/sqlm/408251/spotif...           False
# 94189   https://media.glassdoor.com/sqlm/40988/iba-squ...            True
# 118571  https://media.glassdoor.com/sqlm/266447/opswat...            True
# 29671   https://media.glassdoor.com/sqlm/1925330/helve...            True
#
#                                        header.overviewUrl header.posted  \
# 38076   /Overview/Working-at-New-Zealand-Defence-Force...  Oct 29, 2019
# 15224                                            /spotify   Nov 6, 2019
# 94189       /Overview/Working-at-IBA-EI_IE40988.11,14.htm   Nov 9, 2019
# 118571  /Overview/Working-at-OPSWAT-EI_IE266447.11,17.htm  Oct 16, 2019
# 29671   /Overview/Working-at-Helvetica-Partners-EI_IE1...  Oct 30, 2019
#
#         header.rating  header.saved  header.savedJobId  header.sgocId  \
# 38076             4.2         False                  0              0
# 15224             3.6         False                  0              0
# 94189             3.2         False                  0              0
# 118571            2.9         False                  0              0
# 29671            -0.1         False                  0              0
#
#         header.sponsored  header.userAdmin header.uxApplyType  \
# 38076              False             False                NaN
# 15224               True             False                NaN
# 94189              False             False                NaN
# 118571             False             False                NaN
# 29671              False             False              EMAIL
#
#                 header.featuredVideo header.normalizedJobTitle  \
# 38076                            NaN                       NaN
# 15224   https://youtu.be/03cKoxe7jUI                       NaN
# 94189                            NaN                       NaN
# 118571                           NaN                       NaN
# 29671                            NaN                       NaN
#
#        header.urgencyLabel header.urgencyLabelForMessage  \
# 38076                  NaN                           NaN
# 15224                  NaN                           NaN
# 94189                  NaN                           NaN
# 118571                 NaN                           NaN
# 29671                  NaN                           NaN
#
#        header.urgencyMessage header.needsCommission  header.payHigh  \
# 38076                    NaN                    NaN             NaN
# 15224                    NaN                    NaN             NaN
# 94189                    NaN                    NaN             NaN
# 118571                   NaN                    NaN             NaN
# 29671                    NaN                    NaN             NaN
#
#         header.payLow  header.payMed header.payPeriod  header.salaryHigh  \
# 38076             NaN            NaN              NaN                NaN
# 15224             NaN            NaN              NaN                NaN
# 94189             NaN            NaN              NaN                NaN
# 118571            NaN            NaN              NaN                NaN
# 29671             NaN            NaN              NaN                NaN
#
#         header.salaryLow header.salarySource  \
# 38076                NaN                 NaN
# 15224                NaN                 NaN
# 94189                NaN                 NaN
# 118571               NaN                 NaN
# 29671                NaN                 NaN
#
#                                           job.description  \
# 38076   This is a full time permanent (civ) position\n...
# 15224   We are looking for an Engineering Manager to j...
# 94189   <strong>Particle Therapy:</strong> the next fr...
# 118571  <strong>Senior Software Engineering Manager</s...
# 29671   We are currently looking on behalf of one of o...
#
#            job.discoverDate  job.eolHashCode  job.importConfigId  \
# 38076   2019-10-29T20:30:01        129474080              193018
# 15224   2019-11-06T03:45:06          5588357              130138
# 94189   2019-11-09T00:55:11       1627911603              251946
# 118571  2019-10-16T03:38:07        907156862              145420
# 29671   2019-10-30T15:57:19       -483045443              240641
#
#         job.jobReqId.long  job.jobReqId.int             job.jobSource  \
# 38076        4.194959e+09               NaN  Indeed XML Feed Employer
# 15224        4.026920e+09               NaN                   Jobvite
# 94189        4.171569e+09               NaN  Indeed XML Feed Employer
# 118571       4.042704e+09               NaN             Employer Feed
# 29671        4.086891e+09               NaN  Indeed XML Feed Employer
#
#         job.jobTitleId  job.listingId.long  job.listingId.int  map.country  \
# 38076               -1        3.400759e+09                NaN  New Zealand
# 15224               -1        3.205275e+09                NaN          NaN
# 94189               -1        3.383648e+09                NaN           BE
# 118571           17989        3.388111e+09                NaN           VN
# 29671           112822        3.158804e+09                NaN           CH
#
#           map.employerName  map.lat   map.lng      map.location map.address  \
# 38076     NZ Defence Force -36.8297  174.7994         Devonport         NaN
# 15224              Spotify  59.3333   18.0500         Stockholm         NaN
# 94189                  IBA   0.0000    0.0000           Belgium         NaN
# 118571              OPSWAT  10.7500  106.6667  Ho Chi Minh City         NaN
# 29671   Helvetica Partners  47.3667    8.5500            Zürich         NaN
#
#        map.postalCode                           overview.allBenefitsLink  \
# 38076             NaN  /Benefits/NZ-Defence-Force-UK-Benefits-EI_IE50...
# 15224             NaN  /Benefits/Spotify-UK-Benefits-EI_IE408251.0,7_...
# 94189             NaN  /Benefits/IBA-UK-Benefits-EI_IE40988.0,3_IL.4,...
# 118571            NaN  /Benefits/OPSWAT-UK-Benefits-EI_IE266447.0,6_I...
# 29671             NaN  /Benefits/Helvetica-Partners-UK-Benefits-EI_IE...
#
#                                    overview.allPhotosLink  \
# 38076   /Photos/NZ-Defence-Force-Office-Photos-E505617...
# 15224           /Photos/Spotify-Office-Photos-E408251.htm
# 94189                /Photos/IBA-Office-Photos-E40988.htm
# 118571           /Photos/OPSWAT-Office-Photos-E266447.htm
# 29671   /Photos/Helvetica-Partners-Office-Photos-E1925...
#
#                                  overview.allReviewsLink  \
# 38076      /Reviews/NZ-Defence-Force-Reviews-E505617.htm
# 15224               /Reviews/Spotify-Reviews-E408251.htm
# 94189                    /Reviews/IBA-Reviews-E40988.htm
# 118571               /Reviews/OPSWAT-Reviews-E266447.htm
# 29671   /Reviews/Helvetica-Partners-Reviews-E1925330.htm
#
#                                 overview.allSalariesLink  \
# 38076      /Salary/NZ-Defence-Force-Salaries-E505617.htm
# 15224               /Salary/Spotify-Salaries-E408251.htm
# 94189                    /Salary/IBA-Salaries-E40988.htm
# 118571               /Salary/OPSWAT-Salaries-E266447.htm
# 29671   /Salary/Helvetica-Partners-Salaries-E1925330.htm
#
#         overview.foundedYear                overview.hq  \
# 38076                      0    Wellington, New Zealand
# 15224                   2006          Stockholm, Sweden
# 94189                   1985  Louvain-la-Neuve, Belgium
# 118571                  2002          San Francisco, CA
# 29671                      0        Geneva, Switzerland
#
#                               overview.industry  overview.industryId  \
# 38076                       Government Agencies               200056
# 15224                                  Internet               200063
# 94189          Healthcare Product Manufacturing               200072
# 118571  Enterprise Software & Network Solutions               200061
# 29671                                       NaN                    0
#
#                   overview.revenue         overview.sector  overview.sectorId  \
# 38076       £1 to £2 billion (GBP)              Government              10011
# 15224     Unknown / Non-Applicable  Information Technology              10013
# 94189   £100 to £500 million (GBP)           Manufacturing              10015
# 118571    £10 to £25 million (GBP)  Information Technology              10013
# 29671     Unknown / Non-Applicable                     NaN                  0
#
#                  overview.size overview.stock      overview.type  \
# 38076         10000+ employees            NaN         Government
# 15224   1001 to 5000 employees           SPOT   Company - Public
# 94189   1001 to 5000 employees           IBAB   Company - Public
# 118571    201 to 500 employees            NaN  Company - Private
# 29671        1 to 50 employees            NaN  Company - Private
#
#                                      overview.description  \
# 38076                                                 NaN
# 15224   We’re pioneers.\r\n\r\nOur industry sector did...
# 94189   You'll find Ion Beam Applications (IBA) on the...
# 118571  OPSWAT is a global cybersecurity leader that h...
# 29671                                                 NaN
#
#                                          overview.mission  \
# 38076                                                 NaN
# 15224                                                 NaN
# 94189                                                 NaN
# 118571  OPSWAT is a global cybersecurity leader that h...
# 29671                                                 NaN
#
#              overview.website                         overview.allVideosLink  \
# 38076                     NaN                                            NaN
# 15224         www.spotify.com  https://www.youtube.com/user/spotifybackstage
# 94189   www.iba-worldwide.com                                            NaN
# 118571         www.opswat.com                                            NaN
# 29671                     NaN                                            NaN
#
#         overview.competitors overview.companyVideo   photos  rating.ceo.name  \
# 38076                    NaN                   NaN      NaN     Kevin Short
# 15224                    NaN                   NaN  69878.0        Daniel Ek
# 94189                    NaN                   NaN      NaN  Olivier Legrain
# 118571                   NaN                   NaN  38015.0     Benny Czarny
# 29671                    NaN                   NaN      NaN              NaN
#
#                                          rating.ceo.photo  \
# 38076   https://media.glassdoor.com/people/sql/505617/...
# 15224   https://media.glassdoor.com/people/sql/408251/...
# 94189                                                 NaN
# 118571                                                NaN
# 29671                                                 NaN
#
#                                        rating.ceo.photo2x  \
# 38076   https://media.glassdoor.com/people/sqll/505617...
# 15224   https://media.glassdoor.com/people/sqll/408251...
# 94189                                                 NaN
# 118571                                                NaN
# 29671                                                 NaN
#
#         rating.ceo.ratingsCount  rating.ceoApproval  rating.recommendToFriend  \
# 38076                       6.0                1.00                      0.95
# 15224                     270.0                0.83                      0.59
# 94189                      13.0                0.54                      0.58
# 118571                     50.0                0.48                      0.43
# 29671                       0.0               -0.10                     -0.10
#
#         rating.starRating  reviews salary.country.cc3LetterISO  \
# 38076                 4.2    11677                         NaN
# 15224                 3.6   114025                         GBR
# 94189                 3.2    36900                         NaN
# 118571                2.9    62082                         NaN
# 29671                -0.1   112072                         NaN
#
#        salary.country.ccISO salary.country.continent.continentCode  \
# 38076                   NaN                                    NaN
# 15224                    GB                                     EU
# 94189                   NaN                                    NaN
# 118571                  NaN                                    NaN
# 29671                   NaN                                    NaN
#
#        salary.country.continent.continentName  salary.country.continent.id  \
# 38076                                     NaN                          NaN
# 15224                                  Europe                          4.0
# 94189                                     NaN                          NaN
# 118571                                    NaN                          NaN
# 29671                                     NaN                          NaN
#
#        salary.country.continent.new salary.country.countryFIPS  \
# 38076                           NaN                        NaN
# 15224                         False                         UK
# 94189                           NaN                        NaN
# 118571                          NaN                        NaN
# 29671                           NaN                        NaN
#
#        salary.country.currency.currencyCode  \
# 38076                                   NaN
# 15224                                   GBP
# 94189                                   NaN
# 118571                                  NaN
# 29671                                   NaN
#
#         salary.country.currency.defaultFractionDigits  \
# 38076                                             NaN
# 15224                                             2.0
# 94189                                             NaN
# 118571                                            NaN
# 29671                                             NaN
#
#        salary.country.currency.displayName  salary.country.currency.id  \
# 38076                                  NaN                         NaN
# 15224           United Kingdom Pound (GBP)                         2.0
# 94189                                  NaN                         NaN
# 118571                                 NaN                         NaN
# 29671                                  NaN                         NaN
#
#        salary.country.currency.name salary.country.currency.negativeTemplate  \
# 38076                           NaN                                      NaN
# 15224          United Kingdom Pound                                     $(#)
# 94189                           NaN                                      NaN
# 118571                          NaN                                      NaN
# 29671                           NaN                                      NaN
#
#        salary.country.currency.new salary.country.currency.positiveTemplate  \
# 38076                          NaN                                      NaN
# 15224                        False                                       $#
# 94189                          NaN                                      NaN
# 118571                         NaN                                      NaN
# 29671                          NaN                                      NaN
#
#        salary.country.currency.symbol salary.country.currencyCode  \
# 38076                             NaN                         NaN
# 15224                         &pound;                         GBP
# 94189                             NaN                         NaN
# 118571                            NaN                         NaN
# 29671                             NaN                         NaN
#
#        salary.country.defaultLocale salary.country.defaultName  \
# 38076                           NaN                        NaN
# 15224                         en_UK             United Kingdom
# 94189                           NaN                        NaN
# 118571                          NaN                        NaN
# 29671                           NaN                        NaN
#
#        salary.country.defaultShortName  \
# 38076                              NaN
# 15224                   United Kingdom
# 94189                              NaN
# 118571                             NaN
# 29671                              NaN
#
#        salary.country.employerSolutionsCountry  salary.country.id  \
# 38076                                      NaN                NaN
# 15224                                     True                2.0
# 94189                                      NaN                NaN
# 118571                                     NaN                NaN
# 29671                                      NaN                NaN
#
#        salary.country.longName salary.country.major salary.country.name  \
# 38076                      NaN                  NaN                 NaN
# 15224           United Kingdom                 True      United Kingdom
# 94189                      NaN                  NaN                 NaN
# 118571                     NaN                  NaN                 NaN
# 29671                      NaN                  NaN                 NaN
#
#        salary.country.new  salary.country.population salary.country.shortName  \
# 38076                 NaN                        NaN                      NaN
# 15224               False                 60363602.0                       UK
# 94189                 NaN                        NaN                      NaN
# 118571                NaN                        NaN                      NaN
# 29671                 NaN                        NaN                      NaN
#
#        salary.country.tld salary.country.type salary.country.uniqueName  \
# 38076                 NaN                 NaN                       NaN
# 15224                 .uk                   N            United Kingdom
# 94189                 NaN                 NaN                       NaN
# 118571                NaN                 NaN                       NaN
# 29671                 NaN                 NaN                       NaN
#
#        salary.country.usaCentricDisplayName salary.currency.currencyCode  \
# 38076                                   NaN                          NaN
# 15224                        United Kingdom                          GBP
# 94189                                   NaN                          NaN
# 118571                                  NaN                          NaN
# 29671                                   NaN                          NaN
#
#         salary.currency.defaultFractionDigits salary.currency.displayName  \
# 38076                                     NaN                         NaN
# 15224                                     2.0  United Kingdom Pound (GBP)
# 94189                                     NaN                         NaN
# 118571                                    NaN                         NaN
# 29671                                     NaN                         NaN
#
#         salary.currency.id  salary.currency.name  \
# 38076                  NaN                   NaN
# 15224                  2.0  United Kingdom Pound
# 94189                  NaN                   NaN
# 118571                 NaN                   NaN
# 29671                  NaN                   NaN
#
#        salary.currency.negativeTemplate salary.currency.new  \
# 38076                               NaN                 NaN
# 15224                              $(#)               False
# 94189                               NaN                 NaN
# 118571                              NaN                 NaN
# 29671                               NaN                 NaN
#
#        salary.currency.positiveTemplate salary.currency.symbol  \
# 38076                               NaN                    NaN
# 15224                                $#                &pound;
# 94189                               NaN                    NaN
# 118571                              NaN                    NaN
# 29671                               NaN                    NaN
#
#        salary.lastSalaryDate  salary.salaries     wwfu
# 38076                    NaN          10455.0      NaN
# 15224    2019-10-21T05:41:38         101505.0  12927.0
# 94189                    NaN          32904.0      NaN
# 118571                   NaN          55360.0      NaN
# 29671                    NaN          99801.0      NaN

# %% [markdown]
# ### Explore columns

# %%
# List all columns
glassdoor.columns.to_list()
# Out:
# ['benefits.benefitRatingDecimal',
#  'benefits.comments',
#  'benefits.highlights',
#  'benefits.numRatings',
#  'benefits.employerSummary',
#  'breadCrumbs',
#  'gaTrackerData.category',
#  'gaTrackerData.empId',
#  'gaTrackerData.empName',
#  'gaTrackerData.empSize',
#  'gaTrackerData.expired',
#  'gaTrackerData.industry',
#  'gaTrackerData.industryId',
#  'gaTrackerData.jobId.long',
#  'gaTrackerData.jobId.int',
#  'gaTrackerData.jobTitle',
#  'gaTrackerData.location',
#  'gaTrackerData.locationId',
#  'gaTrackerData.locationType',
#  'gaTrackerData.pageRequestGuid.guid',
#  'gaTrackerData.pageRequestGuid.guidValid',
#  'gaTrackerData.pageRequestGuid.part1',
#  'gaTrackerData.pageRequestGuid.part2',
#  'gaTrackerData.sector',
#  'gaTrackerData.sectorId',
#  'gaTrackerData.profileConversionTrackingParams.trackingCAT',
#  'gaTrackerData.profileConversionTrackingParams.trackingSRC',
#  'gaTrackerData.profileConversionTrackingParams.trackingXSP',
#  'gaTrackerData.jobViewTrackingResult.jobViewDisplayTimeMillis',
#  'gaTrackerData.jobViewTrackingResult.requiresTracking',
#  'gaTrackerData.jobViewTrackingResult.trackingUrl',
#  'header.adOrderId',
#  'header.advertiserType',
#  'header.applicationId',
#  'header.applyButtonDisabled',
#  'header.applyUrl',
#  'header.blur',
#  'header.coverPhoto',
#  'header.easyApply',
#  'header.employerId',
#  'header.employerName',
#  'header.expired',
#  'header.gocId',
#  'header.hideCEOInfo',
#  'header.jobTitle',
#  'header.locId',
#  'header.location',
#  'header.locationType',
#  'header.logo',
#  'header.logo2x',
#  'header.organic',
#  'header.overviewUrl',
#  'header.posted',
#  'header.rating',
#  'header.saved',
#  'header.savedJobId',
#  'header.sgocId',
#  'header.sponsored',
#  'header.userAdmin',
#  'header.uxApplyType',
#  'header.featuredVideo',
#  'header.normalizedJobTitle',
#  'header.urgencyLabel',
#  'header.urgencyLabelForMessage',
#  'header.urgencyMessage',
#  'header.needsCommission',
#  'header.payHigh',
#  'header.payLow',
#  'header.payMed',
#  'header.payPeriod',
#  'header.salaryHigh',
#  'header.salaryLow',
#  'header.salarySource',
#  'job.description',
#  'job.discoverDate',
#  'job.eolHashCode',
#  'job.importConfigId',
#  'job.jobReqId.long',
#  'job.jobReqId.int',
#  'job.jobSource',
#  'job.jobTitleId',
#  'job.listingId.long',
#  'job.listingId.int',
#  'map.country',
#  'map.employerName',
#  'map.lat',
#  'map.lng',
#  'map.location',
#  'map.address',
#  'map.postalCode',
#  'overview.allBenefitsLink',
#  'overview.allPhotosLink',
#  'overview.allReviewsLink',
#  'overview.allSalariesLink',
#  'overview.foundedYear',
#  'overview.hq',
#  'overview.industry',
#  'overview.industryId',
#  'overview.revenue',
#  'overview.sector',
#  'overview.sectorId',
#  'overview.size',
#  'overview.stock',
#  'overview.type',
#  'overview.description',
#  'overview.mission',
#  'overview.website',
#  'overview.allVideosLink',
#  'overview.competitors',
#  'overview.companyVideo',
#  'photos',
#  'rating.ceo.name',
#  'rating.ceo.photo',
#  'rating.ceo.photo2x',
#  'rating.ceo.ratingsCount',
#  'rating.ceoApproval',
#  'rating.recommendToFriend',
#  'rating.starRating',
#  'reviews',
#  'salary.country.cc3LetterISO',
#  'salary.country.ccISO',
#  'salary.country.continent.continentCode',
#  'salary.country.continent.continentName',
#  'salary.country.continent.id',
#  'salary.country.continent.new',
#  'salary.country.countryFIPS',
#  'salary.country.currency.currencyCode',
#  'salary.country.currency.defaultFractionDigits',
#  'salary.country.currency.displayName',
#  'salary.country.currency.id',
#  'salary.country.currency.name',
#  'salary.country.currency.negativeTemplate',
#  'salary.country.currency.new',
#  'salary.country.currency.positiveTemplate',
#  'salary.country.currency.symbol',
#  'salary.country.currencyCode',
#  'salary.country.defaultLocale',
#  'salary.country.defaultName',
#  'salary.country.defaultShortName',
#  'salary.country.employerSolutionsCountry',
#  'salary.country.id',
#  'salary.country.longName',
#  'salary.country.major',
#  'salary.country.name',
#  'salary.country.new',
#  'salary.country.population',
#  'salary.country.shortName',
#  'salary.country.tld',
#  'salary.country.type',
#  'salary.country.uniqueName',
#  'salary.country.usaCentricDisplayName',
#  'salary.currency.currencyCode',
#  'salary.currency.defaultFractionDigits',
#  'salary.currency.displayName',
#  'salary.currency.id',
#  'salary.currency.name',
#  'salary.currency.negativeTemplate',
#  'salary.currency.new',
#  'salary.currency.positiveTemplate',
#  'salary.currency.symbol',
#  'salary.lastSalaryDate',
#  'salary.salaries',
#  'wwfu']

# %%
# Unique values for country names
glassdoor['map.country'].unique()
# Out:
# array(['Poland', nan, 'Italy', 'PK', 'IN', 'IL', 'FR', 'ID', 'HK', 'US',
#        'AE', 'BE', 'South Korea', 'France', 'United Kingdom', 'Malaysia',
#        'ZM', 'NG', 'SG', 'ES', 'CA', 'Austria', 'Ukraine', 'AT', 'RO',
#        'DE', 'SA', 'IT', 'Germany', 'MY', 'AR', 'ZA', 'UA', 'PL',
#        'Israel', 'Thailand', 'TH', 'New Zealand', 'Switzerland', 'CHE',
#        'Netherlands', 'Hong Kong', 'LU', 'Belgium', 'Nigeria',
#        'Indonesia', 'UK', 'Saudi Arabia', 'GB', 'IE', 'GH', 'UG', 'EG',
#        'Australia', 'Nederland', 'AU', 'Mexico', 'India', 'TW', 'Sweden',
#        'PH', 'SK', 'CN', 'Lithuania', 'MM', 'NL', 'Saint Kitts And Nevis',
#        'CZ', 'Turkey', 'ro', 'LT', 'UZ', 'Finland', 'JP', 'United States',
#        'Russia', 'USA', 'RU', 'NZ', 'Portugal', 'Kingdom', 'Spain', 'CH',
#        'DK', 'TR', 'South Africa', 'Serbia', 'Zimbabwe', 'Kenya', 'Japan',
#        'Slovakia', 'Singapore', 'BR', 'China', 'QA', 'Hungary', 'BY',
#        'Romania', 'nl', 'Taiwan', 'Greece', 'MX', 'Ireland',
#        'UNITED STATES', 'SE', 'Czech Republic', 'Denmark', 'Philippines',
#        'KR', 'at', 'EE', 'VN', 'Cyprus', 'Canada', 'SINGAPORE', 'Chile',
#        'United Arab Emirates', 'HU', 'Ghana', 'Tanzania', 'Panama',
#        'Viet Nam', 'UY', 'CR', 'Bulgaria', 'JO', 'Argentina',
#        'Bangladesh', 'Iceland', 'JAMAICA', 'ng', 'vn', 'BD', 'Albania',
#        'Egypt', 'PT', 'Peru', 'Qatar', 'Norway', 'BG', 'PE', 'Malta',
#        'SGP', 'th', 'Dubai (United Arab Emirates)', 'ie', 'MZ',
#        'Cambodia', 'Santa Oliva', 'LB', 'Brazil', '96', 'Kuwait', 'FI',
#        'et', 'NO', 'England', 'sg', 'Bahrain', 'ISR', 'au', 'Slovenia',
#        'CO', 'Colombia', 'it', 'Tunisia', 'TZ', 'Vietnam', 'Croatia',
#        'IRL', 'Oman', 'Costa Rica', 'GR', 'dk', 'OM', 'BF', 'no', 'FRA',
#        'de', 'Luxembourg', 'CL', 'Nicaragua', 'Malawi', 'Latvia',
#        'Sri Lanka', 'FRANCE', 'Taiwan [TW]', 'LV', 'INDIA', 'Munich',
#        'IDN', 'IND', 'HUN', 'Algeria', 'ATA', 'KH', 'QAT', 'gb',
#        'Czech republic', 'AFG', 'Macedonia', 'hk', 'Cameroon', 'HT',
#        'Macedonia, Republic of', 'DJ', 'lk', 'mu', 'ARE', 'RS', 'Jamaica',
#        'ET', 'Dublin, Dublin (Ireland)', 'Uruguay', 'Botswana',
#        'Madagascar', 'MYS', 'CN - China', 'Hong Kong (Hong Kong)', 'gr',
#        'BN', 'PA', 'Deutschland', 'IR', 'cz', 'IRQ', 'Barbados', 'KZ',
#        'IQ', 'ESP', 'Dominican Republic', 'Stockholm', 'ae', 'GE',
#        'Papua New Guinea', 'Japan [JP]', 'Nepal', 'CAN', 'CHN', 'Belarus',
#        'qa', 'France-Saint-Germain', "Côte d'Ivoire", 'AUS', 'KE', 'LY',
#        'Morocco', 'us', 'tr', 'CANADA', 'Wroclaw,', 'MA', 'ca', 'rs',
#        'DNK', 'fr', 'Sp', 'RW', 'Mauritius', 'CY', 'Romania.', 'Armenia',
#        'Iraq', 'ITA', 'MT', 'HO', 'DEU', 'RI', 'Ch', 'LK', 'CRI',
#        'Senegal', 'Ro', 'Pakistan', 'Libya', 'kw', 'Estonia', 'Paraguay',
#        'Venezuela', 'Uganda', 'El Salvador', 'UGA', 'BEL',
#        'Trinidad and Tobago', 'in', 'SY', 'ch', 'Namibia', 'México',
#        'Moldova', 'MK', 'Makati City, Philippines', 'EG - Egypt', 'se',
#        'Bangalore', 'KOR', 'id', 'MU', 'HR', 'TM', 'my', 'Schweiz', 'TN',
#        'br', 'Guernsey', 'Guatemala', 'AO', 'EC', 'LI', 'Korea (South)',
#        'COL', 'Honduras', 'cn', 'lu', 'SZ', 'NLD', 'Mozambique', 'be',
#        'JP - Japan', 'HU - Hungary', 'Kazakhstan', 'KUWAIT', 'Telangana',
#        'Si', 'Korea', 'za', 'Lebanon', 'HN', 'SN', 'MEX',
#        'Bosnia and Herzegovina', 'NE', 'SR', 'BH', 'MD', 'Zambia',
#        'IN-IN', 'CI', 'Brasil', 'Guam', 'Ca', 'Cork (Ireland)', 'ML',
#        'SI', 'ci', 'Sw', 'Jordan', 'Scotland, UK', 'VI', 'BRA', 'BO',
#        'THA', 'Congo,', 'Czech Republic-CZ', 'Azerbaijan', 'Brussels',
#        'KW', 'FIN', 'Reunion', 'Haiti', 'CO - Colombia', 'Malmö', 'GU',
#        'AF', 'hu', '02000', 'Ne', 'Gibraltar', 'Mali', 'eg', 'es',
#        'Munich (Germany)', 'Ecuador', 'San Jose, Costa Rica', 'NP', 'mx',
#        'Bosnia And Herzegovina', 'Rwanda', 'AUT', 'VIR',
#        'Brazil, Colombia', 'NI', 'COSTA RICA', 'AL', 'Ethiopia',
#        'India-India', 'mt', 'jp', 'PS', 'GQ', 'tw', 'DO', 'FR - France',
#        'Dalian', 'PARIS', 'Turks and Caicos Islands', 'IS',
#        'Republic of Macedonia', 'JAPAN', 'hr', 'cm', 'Afghanistan', 'MW',
#        'YE', 'SYR', 'Korea, South', 'MLT', 'SG - Singapore', 'LS',
#        'NIGERIA', 'Cheshire', 'PAKISTAN', 'BI', 'China-China', 'FINLAND',
#        'BS', 'kz', 'Liberia', 'Modena', 'SWE', 'NC', 'TG', 'Uzbekistan',
#        'ita', 'COD', 'DZ', 'TURKEY', 'ar', 'NL - Netherlands',
#        'Karnataka', 'nz', 'BMU', 'Democratic Republic of Congo', 'AM',
#        'Mo', 'Tu', 'cr', 'Tuvalu', 'ARG', 'Georgia', 'Jersey', 'Suisse',
#        'Dubai - United Arab Emirates', 'Bengaluru', 'Scotland', 'GT',
#        'mw', 'San José, Costa Rica', 'SL', 'Lesotho', 'ec', 'ru', 'TWN',
#        'Somalia', 'GN', 'Sudan', 'TUR', 'Djibouti', 'AZ', 'netherlands',
#        'Bermuda', 'BJ', 'GHA', 'Laos', 'TT', 'HKG', 'Sierra Leone',
#        'PL - Poland', 'PG', 'PR', 'PHL', 'MC', 'GG', 'np', 'ke', 'GBR',
#        'USA.', 'Bolivia', 'Bouvet Island', 'NORWAY', 'Samoa',
#        'Jeddah Saudi Arabia', 'PANAMA', 'Zaventem', 'NZL', 'Sa',
#        'Neuchâtel (Switzerland)', 'Chennai', 'MY - Malaysia', 'HONG KONG',
#        'Kyrgyzstan', 'Czech', 'Danmark', 'JAM', 'Colombia, Costa Rica',
#        'Isle of Man', 'Congo', 'SAU', 'ZA - South Africa', 'Gabon', 'CM',
#        'pl', 'Gurgaon', 'In'], dtype=object)

# %% [markdown]
# ### Brazil

# %%
# Select lines related to variations of "Brazil"
glassdoor_br = glassdoor.loc[glassdoor['map.country'].isin(['brasil', 'brazil', 'BRAZIL', 'BRASIL', 'Brasil', 'Brazil', 'Br', 'BR', 'br', 'bR', 'BRA', 'Bra', 'bra'])]

# %%
# Number of rows and columns
glassdoor_br.shape
# Out:
# (1423, 163)

# %%
glassdoor_br.sample(5)
# Out:
#         benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 49321                             0.0           136031.0             136031.0
# 152720                            0.0            96630.0              96630.0
# 9743                              0.0           122943.0             122943.0
# 34621                             4.4            70621.0              70621.0
# 123610                            0.0            15921.0              15921.0
#
#         benefits.numRatings benefits.employerSummary  breadCrumbs  \
# 49321                     0                      NaN       136032
# 152720                    0                      NaN        96631
# 9743                      0                      NaN       122944
# 34621                     5                      NaN        70622
# 123610                    0                      NaN        15921
#
#         gaTrackerData.category  gaTrackerData.empId  \
# 49321                       -1              2881569
# 152720                      -1              2770391
# 9743                        -1              1469776
# 34621                       -1                 7745
# 123610                      -1               759554
#
#                                     gaTrackerData.empName  \
# 49321                                       The1 showroom
# 152720  Unidad Provincial de Enlace y Ejecución de Pro...
# 9743                                               Pipefy
# 34621                         Philip Morris International
# 123610                                        App Academy
#
#        gaTrackerData.empSize  gaTrackerData.expired  \
# 49321                   -1-0                  False
# 152720                  -1-0                  False
# 9743                 201-500                  False
# 34621               10000--1                  False
# 123610                  1-50                  False
#
#                  gaTrackerData.industry  gaTrackerData.industryId  \
# 49321                               NaN                         0
# 152720                              NaN                         0
# 9743       Computer Hardware & Software                    200060
# 34621   Consumer Products Manufacturing                    200069
# 123610      Education Training Services                    200045
#
#         gaTrackerData.jobId.long  gaTrackerData.jobId.int  \
# 49321               3.038043e+09                      NaN
# 152720              3.378138e+09                      NaN
# 9743                3.379032e+09                      NaN
# 34621               3.393899e+09                      NaN
# 123610              3.381832e+09                      NaN
#
#              gaTrackerData.jobTitle gaTrackerData.location  \
# 49321             MARKETING ANALYST              São Paulo
# 152720           Jr Finance Analyst              Fortaleza
# 9743             Purchasing Analyst      Curitiba (Brazil)
# 34621   Regional Commercial Manager               Brasilia
# 123610        Lead Product Designer              São Paulo
#
#         gaTrackerData.locationId gaTrackerData.locationType  \
# 49321                    2479061                       CITY
# 152720                   2436932                       CITY
# 9743                     2387909                       CITY
# 34621                    2494161                       CITY
# 123610                   2479061                       CITY
#
#        gaTrackerData.pageRequestGuid.guid  \
# 49321    0000016e57e9e2cda71170b7d5e9f245
# 152720   0000016e57b29ad293d19e6b36c212bc
# 9743     0000016e57d9df0eb238d2c9e3d4fe59
# 34621    0000016e578f355b9d3ae1fa3bad6a4d
# 123610   0000016e56faffbcb24cf690f38b5f85
#
#         gaTrackerData.pageRequestGuid.guidValid  \
# 49321                                      True
# 152720                                     True
# 9743                                       True
# 34621                                      True
# 123610                                     True
#
#         gaTrackerData.pageRequestGuid.part1  \
# 49321                         1573432976077
# 152720                        1573429353170
# 9743                          1573431926542
# 34621                         1573427033435
# 123610                        1573417320380
#
#         gaTrackerData.pageRequestGuid.part2    gaTrackerData.sector  \
# 49321                  -6408216859901300155                     NaN
# 152720                 -7795275296684240196                     NaN
# 9743                   -5604497971709936039  Information Technology
# 34621                  -7117127796246353331           Manufacturing
# 123610                 -5598829134306648187               Education
#
#         gaTrackerData.sectorId  \
# 49321                        0
# 152720                       0
# 9743                     10013
# 34621                    10015
# 123610                   10009
#
#        gaTrackerData.profileConversionTrackingParams.trackingCAT  \
# 49321                                                 NaN
# 152720                                                NaN
# 9743                                                  NaN
# 34621                                              profi0
# 123610                                                NaN
#
#         gaTrackerData.profileConversionTrackingParams.trackingSRC  \
# 49321                                                 NaN
# 152720                                                NaN
# 9743                                                  NaN
# 34621                                           9505118.0
# 123610                                                NaN
#
#         gaTrackerData.profileConversionTrackingParams.trackingXSP  \
# 49321                                                 NaN
# 152720                                                NaN
# 9743                                                  NaN
# 34621                                           4474593.0
# 123610                                                NaN
#
#         gaTrackerData.jobViewTrackingResult.jobViewDisplayTimeMillis  \
# 49321                                                 NaN
# 152720                                                NaN
# 9743                                                  NaN
# 34621                                                 NaN
# 123610                                                NaN
#
#        gaTrackerData.jobViewTrackingResult.requiresTracking  \
# 49321                                                 NaN
# 152720                                                NaN
# 9743                                                  NaN
# 34621                                                 NaN
# 123610                                                NaN
#
#        gaTrackerData.jobViewTrackingResult.trackingUrl  header.adOrderId  \
# 49321                                              NaN            437149
# 152720                                             NaN            437149
# 9743                                               NaN              7438
# 34621                                              NaN            709701
# 123610                                             NaN             14295
#
#        header.advertiserType  header.applicationId  \
# 49321                GENERAL                     0
# 152720               GENERAL                     0
# 9743                 GENERAL                     0
# 34621               EMPLOYER                     0
# 123610               GENERAL                     0
#
#         header.applyButtonDisabled  \
# 49321                        False
# 152720                       False
# 9743                         False
# 34621                        False
# 123610                       False
#
#                                           header.applyUrl  header.blur  \
# 49321   /partner/jobListing.htm?pos=101&ao=437149&s=58...         True
# 152720  /partner/jobListing.htm?pos=101&ao=437149&s=58...         True
# 9743    /partner/jobListing.htm?pos=101&ao=7438&tgt=AP...         True
# 34621   /partner/jobListing.htm?pos=101&ao=709701&s=58...        False
# 123610  /partner/jobListing.htm?pos=101&ao=14295&tgt=A...         True
#
#                                         header.coverPhoto  header.easyApply  \
# 49321           /static/img/banners/default-ei-banner.jpg             False
# 152720          /static/img/banners/default-ei-banner.jpg             False
# 9743            /static/img/banners/default-ei-banner.jpg              True
# 34621   https://media.glassdoor.com/banner/bh/7745/phi...             False
# 123610          /static/img/banners/default-ei-banner.jpg              True
#
#         header.employerId          header.employerName  header.expired  \
# 49321             2881569                The1 showroom           False
# 152720            2770391                      Externo           False
# 9743              1469776                       Pipefy           False
# 34621                7745  Philip Morris International           False
# 123610             759554                         Hash           False
#
#         header.gocId  header.hideCEOInfo              header.jobTitle  \
# 49321             -1               False            MARKETING ANALYST
# 152720            -1               False           Jr Finance Analyst
# 9743              -1               False           Purchasing Analyst
# 34621             -1               False  Regional Commercial Manager
# 123610            -1               False        Lead Product Designer
#
#         header.locId header.location header.locationType  \
# 49321        2479061       São Paulo                   C
# 152720       2436932       Fortaleza                   C
# 9743         2387909        Curitiba                   C
# 34621        2494161        Brasília                   C
# 123610       2479061       São Paulo                   C
#
#                                               header.logo  \
# 49321   https://media.glassdoor.com/sqls/2881569/the1-...
# 152720                                                NaN
# 9743    https://media.glassdoor.com/sqls/1469776/pipef...
# 34621   https://media.glassdoor.com/sqls/7745/philip-m...
# 123610  https://media.glassdoor.com/sqls/759554/hash-m...
#
#                                             header.logo2x  header.organic  \
# 49321   https://media.glassdoor.com/sqlm/2881569/the1-...            True
# 152720                                                NaN            True
# 9743    https://media.glassdoor.com/sqlm/1469776/pipef...            True
# 34621   https://media.glassdoor.com/sqlm/7745/philip-m...           False
# 123610  https://media.glassdoor.com/sqlm/759554/hash-m...            True
#
#                                        header.overviewUrl header.posted  \
# 49321   /Overview/Working-at-The1-showroom-EI_IE288156...  Oct 29, 2019
# 152720  /Overview/Working-at-Externo-EI_IE2770391.11,1...   Nov 4, 2019
# 9743    /Overview/Working-at-Pipefy-EI_IE1469776.11,17...   Nov 5, 2019
# 34621   /Overview/Working-at-Philip-Morris-Internation...  Oct 22, 2019
# 123610    /Overview/Working-at-Hash-EI_IE759554.11,15.htm   Nov 7, 2019
#
#         header.rating  header.saved  header.savedJobId  header.sgocId  \
# 49321             3.5         False                  0              0
# 152720            4.0         False                  0              0
# 9743              4.4         False                  0              0
# 34621             3.8         False                  0              0
# 123610            4.2         False                  0              0
#
#         header.sponsored  header.userAdmin header.uxApplyType  \
# 49321              False             False                NaN
# 152720             False             False                NaN
# 9743               False             False                API
# 34621               True             False                NaN
# 123610             False             False                API
#
#                 header.featuredVideo header.normalizedJobTitle  \
# 49321                            NaN                       NaN
# 152720                           NaN                       NaN
# 9743                             NaN                       NaN
# 34621   https://youtu.be/QKcwEKNqLS0                       NaN
# 123610                           NaN                       NaN
#
#        header.urgencyLabel header.urgencyLabelForMessage  \
# 49321                  NaN                           NaN
# 152720                 NaN                           NaN
# 9743                   NaN                           NaN
# 34621                  NaN                           NaN
# 123610                 NaN                           NaN
#
#        header.urgencyMessage header.needsCommission  header.payHigh  \
# 49321                    NaN                    NaN             NaN
# 152720                   NaN                    NaN             NaN
# 9743                     NaN                    NaN             NaN
# 34621                    NaN                    NaN             NaN
# 123610                   NaN                    NaN             NaN
#
#         header.payLow  header.payMed header.payPeriod  header.salaryHigh  \
# 49321             NaN            NaN              NaN                NaN
# 152720            NaN            NaN              NaN                NaN
# 9743              NaN            NaN              NaN                NaN
# 34621             NaN            NaN              NaN                NaN
# 123610            NaN            NaN              NaN                NaN
#
#         header.salaryLow header.salarySource  \
# 49321                NaN                 NaN
# 152720               NaN                 NaN
# 9743                 NaN                 NaN
# 34621                NaN                 NaN
# 123610               NaN                 NaN
#
#                                           job.description  \
# 49321   Who We Are\n<br/><br/>\nWe are a premium and i...
# 152720  What are we looking for?\n<br/><br/>\nA profes...
# 9743    Pipefy is currently searching for a Purchasing...
# 34621   <div>Are you inquisitive, creative and self-mo...
# 123610  <h3>Product and Technology</h3><br/><br/>We ar...
#
#            job.discoverDate  job.eolHashCode  job.importConfigId  \
# 49321   2019-10-29T16:38:30      -1792114944              204659
# 152720  2019-11-04T16:00:09        857004154              204659
# 9743    2019-11-05T08:31:24        -24814375               70285
# 34621   2019-10-22T12:17:17       -204593245              199600
# 123610  2019-11-07T15:47:07       -916689759               75613
#
#         job.jobReqId.long  job.jobReqId.int             job.jobSource  \
# 49321        4.107342e+09               NaN  Indeed XML Feed Employer
# 152720       4.164569e+09               NaN  Indeed XML Feed Employer
# 9743         4.169763e+09               NaN              RecruiterBox
# 34621        4.184324e+09               NaN                   avature
# 123610       4.184273e+09               NaN            WorkableHR.com
#
#         job.jobTitleId  job.listingId.long  job.listingId.int map.country  \
# 49321            57568        3.038043e+09                NaN          BR
# 152720           24706        3.378138e+09                NaN          BR
# 9743             55409        3.379032e+09                NaN      Brazil
# 34621           210292        3.393899e+09                NaN      Brazil
# 123610           37255        3.381832e+09                NaN          BR
#
#                                          map.employerName  map.lat  map.lng  \
# 49321                                       The1 showroom -23.5333 -46.6167
# 152720  Unidad Provincial de Enlace y Ejecución de Pro...  -3.7167 -38.5000
# 9743                                               Pipefy -25.4167 -49.2500
# 34621                         Philip Morris International -15.7833 -47.9167
# 123610                                        App Academy -23.5333 -46.6167
#
#        map.location map.address map.postalCode  \
# 49321     São Paulo         NaN            NaN
# 152720    Fortaleza         NaN            NaN
# 9743       Curitiba         NaN            NaN
# 34621      Brasília         NaN            NaN
# 123610    São Paulo         NaN            NaN
#
#                                  overview.allBenefitsLink  \
# 49321   /Benefits/The1-showroom-UK-Benefits-EI_IE28815...
# 152720  /Benefits/Unidad-Provincial-de-Enlace-y-Ejecuc...
# 9743    /Benefits/Pipefy-UK-Benefits-EI_IE1469776.0,6_...
# 34621   /Benefits/Philip-Morris-International-UK-Benef...
# 123610  /Benefits/App-Academy-UK-Benefits-EI_IE759554....
#
#                                    overview.allPhotosLink  \
# 49321    /Photos/The1-showroom-Office-Photos-E2881569.htm
# 152720  /Photos/Unidad-Provincial-de-Enlace-y-Ejecució...
# 9743            /Photos/Pipefy-Office-Photos-E1469776.htm
# 34621   /Photos/Philip-Morris-International-Office-Pho...
# 123610      /Photos/App-Academy-Office-Photos-E759554.htm
#
#                                   overview.allReviewsLink  \
# 49321         /Reviews/The1-showroom-Reviews-E2881569.htm
# 152720  /Reviews/Unidad-Provincial-de-Enlace-y-Ejecuci...
# 9743                 /Reviews/Pipefy-Reviews-E1469776.htm
# 34621   /Reviews/Philip-Morris-International-Reviews-E...
# 123610           /Reviews/App-Academy-Reviews-E759554.htm
#
#                                  overview.allSalariesLink  \
# 49321         /Salary/The1-showroom-Salaries-E2881569.htm
# 152720  /Salary/Unidad-Provincial-de-Enlace-y-Ejecució...
# 9743                 /Salary/Pipefy-Salaries-E1469776.htm
# 34621   /Salary/Philip-Morris-International-Salaries-E...
# 123610           /Salary/App-Academy-Salaries-E759554.htm
#
#         overview.foundedYear        overview.hq  \
# 49321                      0  São Paulo, Brazil
# 152720                     0                NaN
# 9743                    2014  San Francisco, CA
# 34621                   2008       New York, NY
# 123610                  2012  San Francisco, CA
#
#                       overview.industry  overview.industryId  \
# 49321                               NaN                    0
# 152720                              NaN                    0
# 9743       Computer Hardware & Software               200060
# 34621   Consumer Products Manufacturing               200069
# 123610      Education Training Services               200045
#
#                 overview.revenue         overview.sector  overview.sectorId  \
# 49321   Unknown / Non-Applicable                     NaN                  0
# 152720  Unknown / Non-Applicable                     NaN                  0
# 9743    Unknown / Non-Applicable  Information Technology              10013
# 34621    £5 to £10 billion (GBP)           Manufacturing              10015
# 123610  Unknown / Non-Applicable               Education              10009
#
#                overview.size overview.stock      overview.type  \
# 49321                Unknown            NaN  Company - Private
# 152720               Unknown            NaN  Company - Private
# 9743    201 to 500 employees            NaN  Company - Private
# 34621       10000+ employees             PM   Company - Public
# 123610     1 to 50 employees            NaN  Company - Private
#
#                                      overview.description  \
# 49321                                                 NaN
# 152720                                                NaN
# 9743    Pipefy is a cloud-based business process manag...
# 34621   Philip Morris International Inc (PMI) is the l...
# 123610  App Academy is a 3 month immersive web develop...
#
#                                          overview.mission   overview.website  \
# 49321                                                 NaN                NaN
# 152720                                                NaN                NaN
# 9743    Pipefy is The operations excellence platform. ...     www.pipefy.com
# 34621                                                 NaN        www.pmi.com
# 123610                                                NaN  www.appacademy.io
#
#                                    overview.allVideosLink  \
# 49321                                                 NaN
# 152720                                                NaN
# 9743                                                  NaN
# 34621   https://www.youtube.com/channel/UC8Ljkwa0c7Njo...
# 123610                                                NaN
#
#         overview.competitors overview.companyVideo   photos  \
# 49321                    NaN                   NaN      NaN
# 152720                   NaN                   NaN      NaN
# 9743                     NaN                   NaN  75337.0
# 34621                20381.0                   NaN  43242.0
# 123610                   NaN                   NaN      NaN
#
#                 rating.ceo.name  \
# 49321                       NaN
# 152720                      NaN
# 9743            Alessio Alionco
# 34621      André Calantzopoulos
# 123610  Kush Patel, Ned Ruggeri
#
#                                          rating.ceo.photo  \
# 49321                                                 NaN
# 152720                                                NaN
# 9743    https://media.glassdoor.com/people/sql/1469776...
# 34621   https://media.glassdoor.com/people/sql/7745/ph...
# 123610                                                NaN
#
#                                        rating.ceo.photo2x  \
# 49321                                                 NaN
# 152720                                                NaN
# 9743    https://media.glassdoor.com/people/sqll/146977...
# 34621   https://media.glassdoor.com/people/sqll/7745/p...
# 123610                                                NaN
#
#         rating.ceo.ratingsCount  rating.ceoApproval  rating.recommendToFriend  \
# 49321                       0.0               -1.00                      0.58
# 152720                      0.0               -1.00                      1.00
# 9743                       13.0                1.00                      0.95
# 34621                     474.0                0.86                      0.76
# 123610                     23.0                0.89                      0.74
#
#         rating.starRating  reviews salary.country.cc3LetterISO  \
# 49321                 3.5   136032                         NaN
# 152720                4.0    96631                         NaN
# 9743                  4.4   122944                         NaN
# 34621                 3.8    70622                         GBR
# 123610                4.2    15921                         NaN
#
#        salary.country.ccISO salary.country.continent.continentCode  \
# 49321                   NaN                                    NaN
# 152720                  NaN                                    NaN
# 9743                    NaN                                    NaN
# 34621                    GB                                     EU
# 123610                  NaN                                    NaN
#
#        salary.country.continent.continentName  salary.country.continent.id  \
# 49321                                     NaN                          NaN
# 152720                                    NaN                          NaN
# 9743                                      NaN                          NaN
# 34621                                  Europe                          4.0
# 123610                                    NaN                          NaN
#
#        salary.country.continent.new salary.country.countryFIPS  \
# 49321                           NaN                        NaN
# 152720                          NaN                        NaN
# 9743                            NaN                        NaN
# 34621                         False                         UK
# 123610                          NaN                        NaN
#
#        salary.country.currency.currencyCode  \
# 49321                                   NaN
# 152720                                  NaN
# 9743                                    NaN
# 34621                                   GBP
# 123610                                  NaN
#
#         salary.country.currency.defaultFractionDigits  \
# 49321                                             NaN
# 152720                                            NaN
# 9743                                              NaN
# 34621                                             2.0
# 123610                                            NaN
#
#        salary.country.currency.displayName  salary.country.currency.id  \
# 49321                                  NaN                         NaN
# 152720                                 NaN                         NaN
# 9743                                   NaN                         NaN
# 34621           United Kingdom Pound (GBP)                         2.0
# 123610                                 NaN                         NaN
#
#        salary.country.currency.name salary.country.currency.negativeTemplate  \
# 49321                           NaN                                      NaN
# 152720                          NaN                                      NaN
# 9743                            NaN                                      NaN
# 34621          United Kingdom Pound                                     $(#)
# 123610                          NaN                                      NaN
#
#        salary.country.currency.new salary.country.currency.positiveTemplate  \
# 49321                          NaN                                      NaN
# 152720                         NaN                                      NaN
# 9743                           NaN                                      NaN
# 34621                        False                                       $#
# 123610                         NaN                                      NaN
#
#        salary.country.currency.symbol salary.country.currencyCode  \
# 49321                             NaN                         NaN
# 152720                            NaN                         NaN
# 9743                              NaN                         NaN
# 34621                         &pound;                         GBP
# 123610                            NaN                         NaN
#
#        salary.country.defaultLocale salary.country.defaultName  \
# 49321                           NaN                        NaN
# 152720                          NaN                        NaN
# 9743                            NaN                        NaN
# 34621                         en_UK             United Kingdom
# 123610                          NaN                        NaN
#
#        salary.country.defaultShortName  \
# 49321                              NaN
# 152720                             NaN
# 9743                               NaN
# 34621                   United Kingdom
# 123610                             NaN
#
#        salary.country.employerSolutionsCountry  salary.country.id  \
# 49321                                      NaN                NaN
# 152720                                     NaN                NaN
# 9743                                       NaN                NaN
# 34621                                     True                2.0
# 123610                                     NaN                NaN
#
#        salary.country.longName salary.country.major salary.country.name  \
# 49321                      NaN                  NaN                 NaN
# 152720                     NaN                  NaN                 NaN
# 9743                       NaN                  NaN                 NaN
# 34621           United Kingdom                 True      United Kingdom
# 123610                     NaN                  NaN                 NaN
#
#        salary.country.new  salary.country.population salary.country.shortName  \
# 49321                 NaN                        NaN                      NaN
# 152720                NaN                        NaN                      NaN
# 9743                  NaN                        NaN                      NaN
# 34621               False                 60363602.0                       UK
# 123610                NaN                        NaN                      NaN
#
#        salary.country.tld salary.country.type salary.country.uniqueName  \
# 49321                 NaN                 NaN                       NaN
# 152720                NaN                 NaN                       NaN
# 9743                  NaN                 NaN                       NaN
# 34621                 .uk                   N            United Kingdom
# 123610                NaN                 NaN                       NaN
#
#        salary.country.usaCentricDisplayName salary.currency.currencyCode  \
# 49321                                   NaN                          NaN
# 152720                                  NaN                          NaN
# 9743                                    NaN                          NaN
# 34621                        United Kingdom                          GBP
# 123610                                  NaN                          NaN
#
#         salary.currency.defaultFractionDigits salary.currency.displayName  \
# 49321                                     NaN                         NaN
# 152720                                    NaN                         NaN
# 9743                                      NaN                         NaN
# 34621                                     2.0  United Kingdom Pound (GBP)
# 123610                                    NaN                         NaN
#
#         salary.currency.id  salary.currency.name  \
# 49321                  NaN                   NaN
# 152720                 NaN                   NaN
# 9743                   NaN                   NaN
# 34621                  2.0  United Kingdom Pound
# 123610                 NaN                   NaN
#
#        salary.currency.negativeTemplate salary.currency.new  \
# 49321                               NaN                 NaN
# 152720                              NaN                 NaN
# 9743                                NaN                 NaN
# 34621                              $(#)               False
# 123610                              NaN                 NaN
#
#        salary.currency.positiveTemplate salary.currency.symbol  \
# 49321                               NaN                    NaN
# 152720                              NaN                    NaN
# 9743                                NaN                    NaN
# 34621                                $#                &pound;
# 123610                              NaN                    NaN
#
#        salary.lastSalaryDate  salary.salaries    wwfu
# 49321                    NaN         121105.0     NaN
# 152720                   NaN          86045.0     NaN
# 9743                     NaN         109478.0     NaN
# 34621    2019-09-30T00:17:52          62952.0  8063.0
# 123610                   NaN          14194.0     NaN

# %% [markdown]
# ### CSV

# %%
# Export data from Google Colaboratory to local machine 
from google.colab import files
glassdoor_br.to_csv('glassdoor_br.csv') 
files.download('glassdoor_br.csv')
